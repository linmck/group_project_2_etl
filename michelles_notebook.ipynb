# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "divorce.csv"
divorce_df = pd.read_csv(csv_file)
divorce_df.head()
# Out:
#    Atr1  Atr2  Atr3  Atr4  Atr5  Atr6  Atr7  Atr8  Atr9  Atr10  ...  Atr46  \
# 0     2     2     4     1     0     0     0     0     0      0  ...      2
# 1     4     4     4     4     4     0     0     4     4      4  ...      2
# 2     2     2     2     2     1     3     2     1     1      2  ...      3
# 3     3     2     3     2     3     3     3     3     3      3  ...      2
# 4     2     2     1     1     1     1     0     0     0      0  ...      2
#
#    Atr47  Atr48  Atr49  Atr50  Atr51  Atr52  Atr53  Atr54  Class
# 0      1      3      3      3      2      3      2      1      1
# 1      2      3      4      4      4      4      2      2      1
# 2      2      3      1      1      1      2      2      2      1
# 3      2      3      3      3      3      2      2      2      1
# 4      1      2      3      2      2      2      1      0      1
#
# [5 rows x 55 columns]

# %%
df1 = divorce_df.replace([0, 1, 2, 3, 4], ["Never", "Seldom", "Averagely", "Frequently", "Always"])
df2 = df1.replace({"Class":"Seldom"}, "Divorced")
df3 = df2.replace({"Class":"Never"}, "Married")

df3.head(100)
# Out:
#           Atr1        Atr2        Atr3       Atr4        Atr5        Atr6  \
# 0    Averagely   Averagely      Always     Seldom       Never       Never
# 1       Always      Always      Always     Always      Always       Never
# 2    Averagely   Averagely   Averagely  Averagely      Seldom  Frequently
# 3   Frequently   Averagely  Frequently  Averagely  Frequently  Frequently
# 4    Averagely   Averagely      Seldom     Seldom      Seldom      Seldom
# ..         ...         ...         ...        ...         ...         ...
# 95       Never       Never       Never      Never       Never       Never
# 96       Never  Frequently      Seldom      Never       Never       Never
# 97       Never       Never       Never      Never       Never       Never
# 98       Never       Never       Never      Never       Never   Averagely
# 99       Never      Seldom   Averagely     Seldom       Never       Never
#
#           Atr7        Atr8        Atr9       Atr10  ...       Atr46  \
# 0        Never       Never       Never       Never  ...   Averagely
# 1        Never      Always      Always      Always  ...   Averagely
# 2    Averagely      Seldom      Seldom   Averagely  ...  Frequently
# 3   Frequently  Frequently  Frequently  Frequently  ...   Averagely
# 4        Never       Never       Never       Never  ...   Averagely
# ..         ...         ...         ...         ...  ...         ...
# 95       Never       Never       Never      Seldom  ...   Averagely
# 96       Never       Never       Never       Never  ...      Seldom
# 97       Never       Never       Never       Never  ...   Averagely
# 98      Seldom       Never       Never       Never  ...      Always
# 99       Never       Never       Never       Never  ...       Never
#
#         Atr47       Atr48       Atr49       Atr50       Atr51       Atr52  \
# 0      Seldom  Frequently  Frequently  Frequently   Averagely  Frequently
# 1   Averagely  Frequently      Always      Always      Always      Always
# 2   Averagely  Frequently      Seldom      Seldom      Seldom   Averagely
# 3   Averagely  Frequently  Frequently  Frequently  Frequently   Averagely
# 4      Seldom   Averagely  Frequently   Averagely   Averagely   Averagely
# ..        ...         ...         ...         ...         ...         ...
# 95      Never   Averagely   Averagely   Averagely   Averagely   Averagely
# 96     Seldom      Always       Never       Never   Averagely       Never
# 97     Seldom      Seldom       Never       Never       Never      Seldom
# 98  Averagely  Frequently       Never       Never       Never   Averagely
# 99     Seldom   Averagely       Never       Never       Never  Frequently
#
#         Atr53      Atr54     Class
# 0   Averagely     Seldom  Divorced
# 1   Averagely  Averagely  Divorced
# 2   Averagely  Averagely  Divorced
# 3   Averagely  Averagely  Divorced
# 4      Seldom      Never  Divorced
# ..        ...        ...       ...
# 95  Averagely  Averagely   Married
# 96      Never      Never   Married
# 97      Never      Never   Married
# 98     Always     Seldom   Married
# 99  Averagely     Seldom   Married
#
# [100 rows x 55 columns]

# %%
df3.to_csv('updated_df.csv')
